# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# let's be a little pythonic and save typing
years = list(range(1950, 2011, 10))

gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
# create a line chart, years on x-axis, gdp on y axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# %% [markdown]
# **Mistake**
#
# Saving a mistake below... `matplotlib` plots must be executed as an entire cell, I'm assuming. Running them separately creates separate instances of `plt` with the attributes called.

# %%
plt.title("Nominal GDP")

# %%
plt.ylabel("Billions of $")

# %%
plt.show()

# %%
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of $")

plt.show() #actually don't think this is necessary in notebooks

# %% [markdown]
# In general, not really sure why pyplot works. You import a module, then call specific functions from that module, it seems like we act on the module itself instead of calling objects from the module.

# %% [markdown]
# ### Bar Charts

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Ghandi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
# bars are by default width 0.8, so we'll add 0.1 to the left coordinates
# so that each bar is centered

# Personal comment: This is a little stupid. We actually are defining
# the position of each bar on the axis here
# so matplotlib doesn't have any 'smart' placement of the bars?
xs = [i + 0.1 for i, _ in enumerate(movies)]

# %% [markdown]
# Note to self: Let's be less stupid and make a widget out of this.
# https://jakevdp.github.io/blog/2013/12/05/static-interactive-widgets/

# %%
plt.bar(xs, num_oscars)

plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")

# xticks takes locations and labels as arguments
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)

plt.show()

# %% [markdown]
# ### Histograms

# %%
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
decile = lambda grade: grade // 10 * 10

# %%
# remember that time the author forgot to import this?
from collections import Counter

# %%
histogram = Counter(decile(grade) for grade in grades)

# %%
histogram
# Out:
# Counter({80: 4, 70: 3, 0: 2, 90: 2, 100: 1, 60: 1})

# %%
plt.bar([x - 4 for x in histogram.keys()],
       histogram.values(),
       8)
plt.axis([-5, 105, 0, 5])
plt.xticks([10 * i for i in range(11)], ['dumb' for i in range(11)])
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")

# %% [markdown]
# Skipped the next examples -- it was about misleading plots. No new code.
#
# `pp 77-78, Fig 3-4 and 3-5`

# %% [markdown]
# ### Line Charts

# %%
variance = [2**i for i in range(0,9)]
bias = [2**i for i in range(8,-1, -1)]
total_error = [x + y for x, y in zip(variance, bias)]
xs = [i for i, _ in enumerate(variance)]

# %%
# curiosity 
# %timeit [i for i in range(len(variance))]
# %timeit [i for i, _ in enumerate(variance)]
# Out:
# 1000000 loops, best of 3: 1.55 µs per loop
# 1000000 loops, best of 3: 1.58 µs per loop

# %%
plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias, 'r-.', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

plt.legend(loc=9)
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# ### Scatterplots

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = list('abcdefghi') # feels good man. python is dope

# %%
plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                xy=(friend_count, minute_count),
                xytext=(5, -5),
                textcoords='offset points')

#plt.axis([0, 100, 0, 250])
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of Friends")
plt.ylabel("daily minutes spent on the site")
plt.show()
